# %%
num_usuario = input("Por favor escribe un numero sin decimal de tu eleccion: ")
flo_usuario = input("Por favor escribe un numero con decimal de tu eleccion: ")
str_usuario = input("Ahora por favor escribe una palabra de tu eleccion: ")
print("El numero sin decimal que has selecionado es: ", num_usuario)
print("El numero sin decimal que has selecionado es: ", flo_usuario)
print("La palabra que elejiste fue: ", str_usuario)
print("La combinacion de ambas es: ", num_usuario + " "+ flo_usuario + " " + str_usuario)
print(type(num_usuario))
print(type(str_usuario))
print(type(flo_usuario))
print(id(num_usuario))
print(id(str_usuario))
print(id(flo_usuario))
# Out:
# Por favor escribe un numero sin decimal de tu eleccion: 11
# Por favor escribe un numero con decimal de tu eleccion: 11.11
# Ahora por favor escribe una palabra de tu eleccion: Oscar
# El numero sin decimal que has selecionado es:  11
# El numero sin decimal que has selecionado es:  11.11
# La palabra que elejiste fue:  Oscar
# La combinacion de ambas es:  11 11.11 Oscar
# <class 'str'>
# <class 'str'>
# <class 'str'>
# 2091636621744
# 2091636623408
# 2091636622320
